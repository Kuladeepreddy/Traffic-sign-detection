# %%
import os
import glob
from IPython.display import Image,display
HOME = "/content/"
print(HOME)
# Out:
# /content/

# %%
# !pip install ultralytics==8.0.196

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.6/78.2 GB disk)

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets
# Out:
# mkdir: cannot create directory ‘/content//datasets’: File exists
# /content/datasets

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="3P5dvyH8Ychknhy1nXJv")
project = rf.workspace("roboflow-100").project("road-signs-6ih4y")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="3P5dvyH8Ychknhy1nXJv")
project = rf.workspace("aiproject-qdqx2").project("traffic-sign-object-detection")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !mkdir {HOME}/kong
# %cd {HOME}/kong
# Out:
# /content/kong

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="3P5dvyH8Ychknhy1nXJv")
project = rf.workspace("roboflow-100").project("road-signs-6ih4y")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to road-signs-1 in yolov8:: 100%|██████████| 4198/4198 [00:00<00:00, 6645.39it/s]

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data='/content/kong/road-signs-1/data.yaml' epochs=50 imgsz=640
# Out:
# /content
# ...
# 100% 21.5M/21.5M [00:00<00:00, 163MB/s]
# New https://pypi.org/project/ultralytics/8.1.20 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# %cd /content/runs/detect/train2
# Out:
# /content/runs/detect/train2

# %%
# !ls  /content/runs/detect/train2
# Out:
# args.yaml					    R_curve.png		 val_batch0_labels.jpg
# confusion_matrix_normalized.png			    results.csv		 val_batch0_pred.jpg
# confusion_matrix.png				    results.png		 val_batch1_labels.jpg
# events.out.tfevents.1709312439.192396ae5715.6072.0  train_batch0.jpg	 val_batch1_pred.jpg
# F1_curve.png					    train_batch1.jpg	 val_batch2_labels.jpg
# labels_correlogram.jpg				    train_batch2.jpg	 val_batch2_pred.jpg
# labels.jpg					    train_batch3440.jpg  weights
# P_curve.png					    train_batch3441.jpg
# PR_curve.png					    train_batch3442.jpg

# %%
from IPython.display import Image

# %%
Image(filename ='/content/runs/detect/train2/confusion_matrix.png')

# %%
Image(filename = '/content/runs/detect/train2/confusion_matrix_normalized.png')

# %%
Image(filename = '/content/runs/detect/train2/val_batch0_pred.jpg')

# %%
Image(filename = '/content/runs/detect/train2/val_batch1_pred.jpg')

# %%
Image(filename = '/content/runs/detect/train2/val_batch2_pred.jpg')

# %%
# %cd {HOME}
Image(filename='/content/runs/detect/train2/results.png')
# Out:
# /root

# %%
# !yolo task=detect mode=val model='/content/runs/detect/train2/weights/best.pt' data=/content/kong/road-signs-1/data.yaml
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11133711 parameters, 0 gradients, 28.5 GFLOPs
# val: Scanning /content/kong/road-signs-1/valid/labels.cache... 488 images, 0 backgrounds, 0 corrupt: 100% 488/488 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:10<00:00,  2.89it/s]
#                    all        488        529      0.947      0.934      0.961      0.827
#           do_not_enter        488         30      0.983          1      0.995       0.95
#            do_not_stop        488         30      0.946        0.9      0.957      0.896
#          do_not_turn_l        488         34      0.981      0.941      0.987      0.892
#          do_not_turn_r        488         31      0.852      0.968      0.967      0.921
#          do_not_u_turn        488         30      0.934      0.938      0.978       0.86
# ...

# %%
drive_path = 'folder_link = "https://drive.google.com/drive/u/0/folders/1XfmbSvGPE6KUjiIWunXDtmF8VbV4ngPj"'

# %%
# !cp /content/runs/detect/train2/weights/best.pt '{drive_path}/best_model.pt'
# Out:
# cp: cannot create regular file 'folder_link = "https://drive.google.com/drive/u/0/folders/1XfmbSvGPE6KUjiIWunXDtmF8VbV4ngPj"/best_model.pt': No such file or directory
